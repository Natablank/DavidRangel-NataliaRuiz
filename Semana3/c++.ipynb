# %%
# !pip install numpy
# !pip install matplotlib
# !pip install pandas
# Out:
# ...
#      |████████████████████████████████| 15.7 MB 4.7 MB/s
# ...
#      |████████████████████████████████| 11.2 MB 4.6 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 69.3 MB/s
# ...
#      |████████████████████████████████| 4.3 MB 53.2 MB/s
# ...
#      |████████████████████████████████| 895 kB 59.4 MB/s
# ...
#      |████████████████████████████████| 11.3 MB 4.7 MB/s
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dt = pd.read_csv('https://github.com/Natablank/DavidRangel-NataliaRuiz/blob/main/Semana3/Datos.txt')
datos = dt.iloc[:,0].str.split(expand=True)

print(datos)

x = pd.to_numeric(datos.iloc[:,0])
dx = pd.to_numeric(datos.iloc[:,1])

plt.plot(x,dx)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# /tmp/ipykernel_61/1622229739.py in <module>
# ----> 1 dt = pd.read_csv('https://github.com/Natablank/DavidRangel-NataliaRuiz/blob/main/Semana3/Datos.txt')
#       2 datos = dt.iloc[:,0].str.split(expand=True)
#       3
#       4 print(datos)
#       5
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...
